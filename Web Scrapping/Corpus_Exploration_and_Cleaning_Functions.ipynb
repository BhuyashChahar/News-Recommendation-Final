# %% [markdown]
# # DataFrame Stemming

# %%
import pandas as pd

# %%
df1 = pd.read_csv('IBTimes.csv')
df2 = pd.read_csv('Hindu.csv')
df3 = pd.read_csv('IndiaToday.csv')

# %%
def remove_redun_rows(df, default_cols, cont_col_subset = ["Category", "Headline", "Summary", "Entire_News", "News_Link"], meta_col_subset = ["Date", "Time"]):
    """It removes faulty or duplicate rows
    If there are more columns in the given dataframe than default, this removes those rows that have such more columns. 
    If there are less columns in the given dataframe than default, it returns "None", thereby marking them unusable. 
    If there are duplicated content in any "cont_col_subset", it drops the extra rows except the latest entry.
    If there are rows with missing values for important columns, it removes such rows. 
    If there are rows with missing values for non-important columns, it ignores them, but informs there existence. 
    It returns the trimmed dataframe as the output in all cases except when the number of columns are less than default,
    and prints any missing values in non-important columns"""
    skip = False
    if list(df.columns) != list(default_cols):
        if len(df.columns) == len(default_cols):
            print("There seems to be some error in columns names")
        elif len(df.columns) < len(default_cols):
            print("The given DataFrame seems to have some missing columns")
            df = None # Marking the df useless
            skip = True # Skipping the DataFrame operations
        elif len(df.columns) > len(default_cols):
            print("The given DataFrame seems to have more columns than required")
            df_xtra_col_idx = df.loc[:, df.columns[len(default_cols):]].isnull().any(axis = 1)
            df = df.loc[df.index[df_xtra_col_idx], default_cols]
    if not skip:
        df = df.drop_duplicates(subset = cont_col_subset)
        df = df.dropna(subset = cont_col_subset+meta_col_subset)
        non_imp_cols = list(set(default_cols)-set(cont_col_subset+meta_col_subset))
        display(df.loc[df.loc[:, non_imp_cols].isnull().any(axis = 1), :])
    return df

# %%
frames=[df1, df2, df3]
Scraped_News=pd.concat(frames, ignore_index=True)

# %%
display(Scraped_News)
# Out:
#       Unnamed: 0            Date       Time Category Sub-Category  \
# 0              0      2022-03-14   16:50:19  society   fact-check
# 1              1      2022-02-21   21:54:03  society   fact-check
# 2              2      2022-02-16   01:03:07  society   fact-check
# 3              3      2022-02-09   02:12:06  society   fact-check
# 4              4      2022-02-08   18:20:45  society   fact-check
# ...          ...             ...        ...      ...          ...
# 2377         424  March 23, 2022  12:24 IST  science
# 2378         425  March 23, 2022  11:55 IST  science
# 2379         426  March 23, 2022  10:41 IST  science
# 2380         427  March 22, 2022  17:14 IST  science
# 2381         428  March 22, 2022  16:15 IST  science
#
#                                                Headline  \
# 0     Fact check: No, Ugandan cop didn't hit journal...
# 1     Fact check: Murdered Bajrang Dal activist not ...
# 2     Fact check: Nandan Nilekani isn't launching cr...
# 3     Fact check: Indian flag not replaced by saffro...
# 4     Fact check: Viral video falsely links J&K poli...
# ...                                                 ...
# 2377  Ingenuity helicopter aces 22nd flight on Mars ...
# 2378  What is GSAT-7B satellite that will boost Indi...
# 2379  Arctic missing ice that could have covered twi...
# 2380  India not alone in facing heatwave, both of Ea...
# 2381  This is how 5,000 planets discovered beyond ou...
#
#                                             Entire_News  \
# 0      A Ugandan cop is creating a buzz on social me...
# 1      The brutal murder of Bajrang Dal activist in ...
# 2      Discussion over cryptocurrency took prominenc...
# 3      Shocking details are emerging from the widesp...
# 4      University of Kashmir students are protesting...
# ...                                                 ...
# 2377  The little helicopter that has surprised its m...
# 2378  The Indian Army is set to get a long-awaited d...
# 2379  With climate change raging and impacts seen ac...
# 2380  With the climate crisis becoming rampant and e...
# 2381  The universe is filled with billions of worlds...
#
#                                                  Author  \
# 0     \nSami Khan                                   ...
# 1     \nSami Khan                                   ...
# 2     \nSami Khan                                   ...
# 3     \nSami Khan                                   ...
# 4     \nSami Khan                                   ...
# ...                                                 ...
# 2377                               India Today Web Desk
# 2378                               India Today Web Desk
# 2379                               India Today Web Desk
# 2380                               India Today Web Desk
# 2381                               India Today Web Desk
#
#                                               News_Link
# 0     https://www.ibtimes.co.in/fact-check-no-uganda...
# 1     https://www.ibtimes.co.in/fact-check-murdered-...
# 2     https://www.ibtimes.co.in/fact-check-nandan-ni...
# 3     https://www.ibtimes.co.in/fact-check-indian-fl...
# 4     https://www.ibtimes.co.in/fact-check-viral-vid...
# ...                                                 ...
# 2377  https://www.indiatoday.in/science/story/ingenu...
# 2378  https://www.indiatoday.in/science/story/what-i...
# 2379  https://www.indiatoday.in/science/story/climat...
# 2380  https://www.indiatoday.in/science/story/earth-...
# 2381  https://www.indiatoday.in/science/story/nasa-5...
#
# [2382 rows x 9 columns]

# %%
display(Scraped_News.info(), Scraped_News.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2382 entries, 0 to 2381
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    2382 non-null   int64
#  1   Date          2382 non-null   object
#  2   Time          2382 non-null   object
#  3   Category      2382 non-null   object
#  4   Sub-Category  2382 non-null   object
#  5   Headline      2382 non-null   object
#  6   Entire_News   2382 non-null   object
#  7   Author        2381 non-null   object
#  8   News_Link     2382 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 167.6+ KB
# None
#         Unnamed: 0
# count  2382.000000
# mean    462.314861
# std     305.881143
# min       0.000000
# 25%     204.000000
# 50%     410.500000
# 75%     706.000000
# max    1146.000000

# %%
non_redun_Scraped_News = remove_redun_rows(Scraped_News, default_cols = Scraped_News.columns)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/y3/l8tqgpkj4dlb0dl6cs91lhq40000gn/T/ipykernel_27575/1004406590.py in ?()
# ----> 1 non_redun_Scraped_News = remove_redun_rows(Scraped_News, default_cols = Scraped_News.columns)
#
# /var/folders/y3/l8tqgpkj4dlb0dl6cs91lhq40000gn/T/ipykernel_27575/3206560823.py in ?(df, default_cols, cont_col_subset, meta_col_subset)
#      19             print("The given DataFrame seems to have more columns than required")
#      20             df_xtra_col_idx = df.loc[:, df.columns[len(default_cols):]].isnull().any(axis = 1)
#      21             df = df.loc[df.index[df_xtra_col_idx], default_cols]
#      22     if not skip:
# ---> 23         df = df.drop_duplicates(subset = cont_col_subset)
#      24         df = df.dropna(subset = cont_col_subset+meta_col_subset)
#      25         non_imp_cols = list(set(default_cols)-set(cont_col_subset+meta_col_subset))
#      26         display(df.loc[df.loc[:, non_imp_cols].isnull().any(axis = 1), :])
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py in ?(self, subset, keep, inplace, ignore_index)
#    6814
#    6815         inplace = validate_bool_kwarg(inplace, "inplace")
#    6816         ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
#    6817
# -> 6818         result = self[-self.duplicated(subset, keep=keep)]
#    6819         if ignore_index:
#    6820             result.index = default_index(len(result))
#    6821
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py in ?(self, subset, keep)
#    6946         # Otherwise, raise a KeyError, same as if you try to __getitem__ with a
#    6947         # key that doesn't exist.
#    6948         diff = set(subset) - set(self.columns)
#    6949         if diff:
# -> 6950             raise KeyError(Index(diff))
#    6951
#    6952         if len(subset) == 1 and self.columns.is_unique:
#    6953             # GH#45236 This is faster than get_group_index below
#
# KeyError: Index(['Summary'], dtype='object')

# %%
non_redun_Scraped_News
# Out:
#                     Date          Time       Category Subcategory  \
# 0              28-Jan-21    7:35:55 AM         Sports   Badminton
# 1              27-Jan-21    4:51:08 PM         Sports   Badminton
# 2              27-Jan-21    8:30:22 AM         Sports   Badminton
# 3              24-Jan-21    7:03:06 PM         Sports   Badminton
# 4              23-Jan-21    7:58:44 PM         Sports   Badminton
# ...                  ...           ...            ...         ...
# 24882  February 06, 2021  12:17 am IST  entertainment  television
# 24883  February 03, 2021  12:23 pm IST  entertainment  television
# 24884  February 01, 2021  11:56 pm IST  entertainment  television
# 24885   January 29, 2021   2:28 pm IST  entertainment  television
# 24886   January 28, 2021  11:51 pm IST  entertainment  television
#
#                                                 Headline  \
# 0      Patient pays… almost: Srikanth tries to stay i...
# 1      BWF World Tour Finals: Fighting PV Sindhu lose...
# 2      World Tour Finals Preview: PV Sindhu, recharge...
# 3      Satwiksairaj’s offence gets neutralised by sav...
# 4      Dream run of Indian doubles pairs end with sem...
# ...                                                  ...
# 24882  Bigg Boss 14 February 5, 2021, Written Update:...
# 24883  A Tour Of Shaheer Sheikh And Ruchikaa Kapoor's...
# 24884  Bigg Boss 14: Nikki Tamboli, Rahul Vaidya's Fi...
# 24885  Identify The Comedy Star In This Pic From 28 Y...
# 24886  Bigg Boss 14 January 28, 2021 Written Update: ...
#
#                                                  Summary  \
# 0      Kidambi Srikanth gritted it out and though he ...
# 1      This was PV Sindhu's 16th defeat to Tai Tzu Yi...
# 2      With the Indian having played more matches tha...
# 3      Satwiksairaj Rankireddy uses big smash to kill...
# 4      Up against the world number three Thai pair, S...
# ...                                                  ...
# 24882  Bigg Boss 14: Devoleena lashed out at Arshi fo...
# 24883  Pictures from Shaheer and Ruchikaa's swanky ap...
# 24884  After a war of words, Nikki Tamboli agreed to ...
# 24885  The young Kapil Sharma in the photo is barely ...
# 24886  Bigg Boss 14: According to the task, the house...
#
#                                              Entire_News  \
# 0      In Test cricket’s season of spectacular stubbo...
# 1      World champion shuttler P V Sindhu went down f...
# 2      Carolina Marin (50 total) played 24 tournament...
# 3      One would have to be blind to not figure that ...
# 4      The Indian mixed doubles pair of Satwiksairaj ...
# ...                                                  ...
# 24882  On the 125th day in the Bigg Boss house, Devol...
# 24883  TV actors Shaheer Sheikh and Ruchikaa Kapoor, ...
# 24884  Monday's episode of Bigg Boss 14 was fulll of ...
# 24885  Every now and then, actor-comedian Kapil Sharm...
# 24886  Rivalry is one of the important factors in the...
#
#                       Author  \
# 0               Shivani naik
# 1                        Pti
# 2               Shivani naik
# 3               Shivani naik
# 4                        Pti
# ...                      ...
# 24882  Aakanksha Raghuvanshi
# 24883  Aakanksha Raghuvanshi
# 24884         Nilanjana Basu
# 24885         Nilanjana Basu
# 24886  Aakanksha Raghuvanshi
#
#                                                News_Link
# 0      https://indianexpress.com/article/sports/badmi...
# 1      https://indianexpress.com/article/sports/badmi...
# 2      https://indianexpress.com/article/sports/badmi...
# 3      https://indianexpress.com/article/sports/badmi...
# 4      https://indianexpress.com/article/sports/badmi...
# ...                                                  ...
# 24882  https://www.ndtv.com/entertainment/bigg-boss-1...
# 24883  https://www.ndtv.com/entertainment/a-tour-of-s...
# 24884  https://www.ndtv.com/entertainment/bigg-boss-1...
# 24885  https://www.ndtv.com/entertainment/heres-what-...
# 24886  https://www.ndtv.com/entertainment/bigg-boss-1...
#
# [22753 rows x 9 columns]

# %% [markdown]
# # Date and Time Reformatting

# %%
import datetime

pub_dt_format = {"indianexpress": "%d-%b-%y %I:%M:%S %p" , "republicworld": "%d %B, %Y %H:%M IST", "dailymail": "%d/%m/%y %H:%M", "indiatoday": "%d-%b-%y %H:%M IST", "ibtimes": "%d-%b-%y %H:%M IST", "ndtv": "%B %d, %Y %I:%M %p IST"}

def dt_merge(df, input_cols = ["Date", "Time"], target_col = "Datetime"):
    if target_col not in df.columns:
        df.insert(0, target_col, df[input_cols].agg(" ".join, axis = 1))
        df = df.drop(["Date", "Time"], axis = 1)
    else:
        print("'{}' already exists in the given DataFrame".format(target_col))
    return df

def dt_reformat(ds, id_col = "News_Link", target_col = "Datetime", date_format_dict = pub_dt_format):
    """Note: This function should only be applied on the Corpus DataFrame by using df.apply(dt_reformat, axis = 1)"""
    for k, v in date_format_dict.items():
        if k in ds.loc[id_col]:
            dt_obj = pd.to_datetime(ds.loc[target_col], format=v, infer_datetime_format=True)
            iso_dttime = dt_obj.strftime("%Y-%m-%d %H:%M:%S")
            ds.loc[target_col] = iso_dttime
    return ds

# %%
non_redun_Scraped_News = dt_merge(non_redun_Scraped_News)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 non_redun_Scraped_News = dt_merge(non_redun_Scraped_News)
#
# NameError: name 'non_redun_Scraped_News' is not defined

# %%
non_redun_Scraped_News
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 non_redun_Scraped_News
#
# NameError: name 'non_redun_Scraped_News' is not defined

# %% [markdown]
# # Category Reformatting

# %%
def cat_reformat(df):
    df['Category'] = df['Category'].replace(['business'],'Business')
    df['Category'] = df['Category'].replace(['Business-news'],'Business')
    df['Category'] = df['Category'].replace(['India-news'],'India')
    df['Category'] = df['Category'].replace(['Sports-news'],'Sports')
    df['Category'] = df['Category'].replace(['sports'],'Sports')
    df['Category'] = df['Category'].replace(['tvshowbiz'],'Entertainment')
    df['Category'] = df['Category'].replace(['entertainment'],'Entertainment')
    df['Category'] = df['Category'].replace(['Television'],'Entertainment')
    df['Category'] = df['Category'].replace(['Entertainment-news'],'Entertainment')
    df['Category'] = df['Category'].replace(['Technology-news'],'Technology')
    df['Category'] = df['Category'].replace(['technology'],'Technology')
    df['Category'] = df['Category'].replace(['World-news'],'World')
    df['Category'] = df['Category'].replace(['news'],'News')
    df['Category'] = df['Category'].replace(['society'],'Society')
    df['Category'] = df['Category'].replace(['Data-intelligence-unit'],'News')
    df['Category'] = df['Category'].replace(['Movies'],'Entertainment')
    df['Category'] = df['Category'].replace(['Education-today'],'Education')
    df['Category'] = df['Category'].replace(['Cities'],'India')
    return df

# %%
non_redun_Scraped_News = cat_reformat(non_redun_Scraped_News)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 non_redun_Scraped_News = cat_reformat(non_redun_Scraped_News)
#
# NameError: name 'non_redun_Scraped_News' is not defined

# %%
non_redun_Scraped_News
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 non_redun_Scraped_News
#
# NameError: name 'non_redun_Scraped_News' is not defined

# %% [markdown]
# # Further Exploration

# %%
non_redun_Scraped_News = non_redun_Scraped_News.apply(dt_reformat, axis = 1)

# %%
non_redun_Scraped_News
# Out:
#                   Datetime       Category Subcategory  \
# 0      2021-01-28 07:35:55         Sports   Badminton
# 1      2021-01-27 16:51:08         Sports   Badminton
# 2      2021-01-27 08:30:22         Sports   Badminton
# 3      2021-01-24 19:03:06         Sports   Badminton
# 4      2021-01-23 19:58:44         Sports   Badminton
# ...                    ...            ...         ...
# 24882  2021-02-06 00:17:00  Entertainment  television
# 24883  2021-02-03 12:23:00  Entertainment  television
# 24884  2021-02-01 23:56:00  Entertainment  television
# 24885  2021-01-29 14:28:00  Entertainment  television
# 24886  2021-01-28 23:51:00  Entertainment  television
#
#                                                 Headline  \
# 0      Patient pays… almost: Srikanth tries to stay i...
# 1      BWF World Tour Finals: Fighting PV Sindhu lose...
# 2      World Tour Finals Preview: PV Sindhu, recharge...
# 3      Satwiksairaj’s offence gets neutralised by sav...
# 4      Dream run of Indian doubles pairs end with sem...
# ...                                                  ...
# 24882  Bigg Boss 14 February 5, 2021, Written Update:...
# 24883  A Tour Of Shaheer Sheikh And Ruchikaa Kapoor's...
# 24884  Bigg Boss 14: Nikki Tamboli, Rahul Vaidya's Fi...
# 24885  Identify The Comedy Star In This Pic From 28 Y...
# 24886  Bigg Boss 14 January 28, 2021 Written Update: ...
#
#                                                  Summary  \
# 0      Kidambi Srikanth gritted it out and though he ...
# 1      This was PV Sindhu's 16th defeat to Tai Tzu Yi...
# 2      With the Indian having played more matches tha...
# 3      Satwiksairaj Rankireddy uses big smash to kill...
# 4      Up against the world number three Thai pair, S...
# ...                                                  ...
# 24882  Bigg Boss 14: Devoleena lashed out at Arshi fo...
# 24883  Pictures from Shaheer and Ruchikaa's swanky ap...
# 24884  After a war of words, Nikki Tamboli agreed to ...
# 24885  The young Kapil Sharma in the photo is barely ...
# 24886  Bigg Boss 14: According to the task, the house...
#
#                                              Entire_News  \
# 0      In Test cricket’s season of spectacular stubbo...
# 1      World champion shuttler P V Sindhu went down f...
# 2      Carolina Marin (50 total) played 24 tournament...
# 3      One would have to be blind to not figure that ...
# 4      The Indian mixed doubles pair of Satwiksairaj ...
# ...                                                  ...
# 24882  On the 125th day in the Bigg Boss house, Devol...
# 24883  TV actors Shaheer Sheikh and Ruchikaa Kapoor, ...
# 24884  Monday's episode of Bigg Boss 14 was fulll of ...
# 24885  Every now and then, actor-comedian Kapil Sharm...
# 24886  Rivalry is one of the important factors in the...
#
#                       Author  \
# 0               Shivani naik
# 1                        Pti
# 2               Shivani naik
# 3               Shivani naik
# 4                        Pti
# ...                      ...
# 24882  Aakanksha Raghuvanshi
# 24883  Aakanksha Raghuvanshi
# 24884         Nilanjana Basu
# 24885         Nilanjana Basu
# 24886  Aakanksha Raghuvanshi
#
#                                                News_Link
# 0      https://indianexpress.com/article/sports/badmi...
# 1      https://indianexpress.com/article/sports/badmi...
# 2      https://indianexpress.com/article/sports/badmi...
# 3      https://indianexpress.com/article/sports/badmi...
# 4      https://indianexpress.com/article/sports/badmi...
# ...                                                  ...
# 24882  https://www.ndtv.com/entertainment/bigg-boss-1...
# 24883  https://www.ndtv.com/entertainment/a-tour-of-s...
# 24884  https://www.ndtv.com/entertainment/bigg-boss-1...
# 24885  https://www.ndtv.com/entertainment/heres-what-...
# 24886  https://www.ndtv.com/entertainment/bigg-boss-1...
#
# [22753 rows x 8 columns]

# %%
non_redun_Scraped_News.to_csv("Final_Clean_Corpus.csv")

# %%
non_redun_Scraped_News.describe()
# Out:
#                    Datetime       Category Subcategory  \
# count                 22753          22753       22037
# unique                20611             13         141
# top     2021-03-13 09:00:00  Entertainment   bollywood
# freq                     10           4554         435
#
#                                                  Headline  \
# count                                               22753
# unique                                              22733
# top     Mist-shrouded churches, eerie shipwrecks and m...
# freq                                                    3
#
#                                                   Summary  \
# count                                               22753
# unique                                              22674
# top     Flipkart Sale on electronics is back and the w...
# freq                                                    4
#
#                                               Entire_News  \
# count                                               22753
# unique                                              22700
# top     PromotedListen to the latest songs, only on Ji...
# freq                                                   17
#
#                                                   Author  \
# count                                              22303
# unique                                              1184
# top     Associated press television news
# freq                                                1845
#
#                                                 News_Link
# count                                               22753
# unique                                              22749
# top     https://www.republicworld.com/india-news/law-a...
# freq                                                    2

# %%
remove_redun_rows(non_redun_Scraped_News, default_cols = non_redun_Scraped_News.columns, meta_col_subset=["Datetime"]).describe()
# Out:
#                   Datetime       Category  Subcategory  \
# 10724  2021-03-17 09:57:00          India          NaN
# 10725  2021-03-17 09:38:00          India          NaN
# 10726  2021-03-17 09:08:00          India          NaN
# 10727  2021-03-17 08:46:00          India          NaN
# 10728  2021-03-17 07:18:00          India          NaN
# ...                    ...            ...          ...
# 15724  2020-01-19 15:39:00  Entertainment  Top-stories
# 24823  https://www.ndtv.com/entertainment/brad-pitt-b...
# 24824  https://www.ndtv.com/entertainment/priyanka-ch...
# 24825  https://www.ndtv.com/entertainment/kabir-khan-...
# 24826  https://www.ndtv.com/entertainment/baywatch-re...
# 24827  https://www.ndtv.com/entertainment/irrfan-khan...
# 24828  https://www.ndtv.com/entertainment/jimmy-kimme...
# 24830  https://www.ndtv.com/entertainment/guardians-o...
# 24835  https://www.ndtv.com/entertainment/johnny-depp...
# 24837  https://www.ndtv.com/entertainment/javier-bard...
# 24839  https://www.ndtv.com/entertainment/how-guardia...

# %%
for i in non_redun_Scraped_News.loc[temp_i_list, "Entire_News"].tolist():
    print(i)
    print("-"*115)
# Out:
# PromotedListen to the latest songs, only on JioSaavn.com
# -------------------------------------------------------------------------------------------------------------------
# PromotedListen to the latest songs, only on JioSaavn.com
# -------------------------------------------------------------------------------------------------------------------
# PromotedListen to the latest songs, only on JioSaavn.com
# -------------------------------------------------------------------------------------------------------------------
# PromotedListen to the latest songs, only on JioSaavn.com
# -------------------------------------------------------------------------------------------------------------------
# PromotedListen to the latest songs, only on JioSaavn.com
# -------------------------------------------------------------------------------------------------------------------
# PromotedListen to the latest songs, only on JioSaavn.com
# -------------------------------------------------------------------------------------------------------------------
# PromotedListen to the latest songs, only on JioSaavn.com
# -------------------------------------------------------------------------------------------------------------------
# PromotedListen to the latest songs, only on JioSaavn.com
# -------------------------------------------------------------------------------------------------------------------
# PromotedListen to the latest songs, only on JioSaavn.com
# -------------------------------------------------------------------------------------------------------------------
# PromotedListen to the latest songs, only on JioSaavn.com
# -------------------------------------------------------------------------------------------------------------------
# PromotedListen to the latest songs, only on JioSaavn.com
# -------------------------------------------------------------------------------------------------------------------
# PromotedListen to the latest songs, only on JioSaavn.com
# -------------------------------------------------------------------------------------------------------------------
# PromotedListen to the latest songs, only on JioSaavn.com
# -------------------------------------------------------------------------------------------------------------------
# PromotedListen to the latest songs, only on JioSaavn.com
# -------------------------------------------------------------------------------------------------------------------
# PromotedListen to the latest songs, only on JioSaavn.com
# -------------------------------------------------------------------------------------------------------------------
# PromotedListen to the latest songs, only on JioSaavn.com
# -------------------------------------------------------------------------------------------------------------------
# PromotedListen to the latest songs, only on JioSaavn.com
# -------------------------------------------------------------------------------------------------------------------

# %%
temp_i_list = list()
for i in non_redun_Scraped_News.index:
    if non_redun_Scraped_News.loc[i, "Summary"].startswith("The state-run oil refiner Indian Oil Corpor"):
        print(i)
        temp_i_list.append(i)
# Out:
# 24535
# 24554
# 24571
# 24589

# %%
for i in non_redun_Scraped_News.loc[temp_i_list, "Entire_News"].tolist():
    print(i)
    print("-"*115)
# Out:
# Petrol, Diesel Prices Today: Petrol and diesel prices remained unchanged across the four metros for 19 days in a row on Thursday, March 18. The state-run oil refiner Indian Oil Corporation had last raised fuel prices on February 27 to an all-time high of Rs 91.17 in the national capital. Since then, fuel rates have been steady across the four metro cities. As of now, the highest fuel prices are in Mumbai where petrol is at Rs 97.57 per litre and diesel at Rs 88.60 per litre. (Also Read: How To Find Latest Petrol, Diesel Rates In Your City) The oil marketing companies - Bharat Petroleum, Indian Oil Corporation and Hindustan Petroleum align the rates of domestic fuel with the global benchmarks, by taking into account any revisions in the foreign exchange rates. Any changes in fuel rates are implemented with effect from 6 am each day. The domestic petrol and diesel prices vary across states due to the value-added tax (VAT). PromotedListen to the latest songs, only on JioSaavn.com Meanwhile, oil prices dropped for a fifth day on Thursday after official data showed a sustained rise in U.S. crude and fuel inventories, while the ever-present pandemic clouded the demand outlook. Brent crude was down 12 cents, or 0.2 per cent, at $67.88 a barrel after dropping by 0.6 per cent on Wednesday. U.S. oil was also down 12 cents or 0.2 per cent at $64.48 a barrel, having fallen 0.3 per cent in the previous session.
# -------------------------------------------------------------------------------------------------------------------
# Petrol, Diesel Prices Today: Petrol and diesel prices remained unchanged across the four metros for 18 days in a row on Wednesday, March 17. The state-run oil refiner Indian Oil Corporation had last raised fuel prices on February 27 to an all-time high of Rs 91.17 in the national capital. Since then, fuel rates have been steady across the four metro cities. As of now, the highest fuel prices are in Mumbai where petrol is at Rs 97.57 per litre and diesel at Rs 88.60 per litre. (Also Read: How To Find Latest Petrol, Diesel Rates In Your City) The oil marketing companies - Bharat Petroleum, Indian Oil Corporation and Hindustan Petroleum align the rates of domestic fuel with the global benchmarks, by taking into account any revisions in the foreign exchange rates. Any changes in fuel rates are implemented with effect from 6 am each day. The domestic petrol and diesel prices vary across states due to the value-added tax (VAT). Meanwhile, oil prices edged lower on Monday, pulling back from early gains fostered on strong Chinese economic news and ongoing supply restraint from major oil producers. Brent crude futures for May settled at $68.88 a barrel, losing 34 cents. U.S. West Texas Intermediate crude for April settled at $65.39 a barrel, shedding 22 cents. PromotedListen to the latest songs, only on JioSaavn.com
# 24571             Petrol, Diesel Rates Steady On Tuesday
# 24589           Petrol, Diesel Rates Unchanged On Monday
#
#                                                  Summary  \
# 24535  The state-run oil refiner Indian Oil Corporati...
# 24554  The state-run oil refiner Indian Oil Corporati...
# 24571  The state-run oil refiner Indian Oil Corporati...
# 24589  The state-run oil refiner Indian Oil Corporati...
#
#                                              Entire_News         Author  \
# 24535  Petrol, Diesel Prices Today: Petrol and diesel...  Peter Noronha
# 24554  Petrol, Diesel Prices Today: Petrol and diesel...  Peter Noronha
# 24571  Petrol, Diesel Prices Today: Petrol and diesel...  Peter Noronha
# 24589  Petrol, Diesel Prices Today: Petrol and diesel...  Peter Noronha
#
#                                                News_Link
# 24535  https://www.ndtv.com/business/petrol-diesel-pr...
# 24554  https://www.ndtv.com/business/petrol-diesel-pr...
# 24571  https://www.ndtv.com/business/petrol-diesel-pr...
# 24589  https://www.ndtv.com/business/petrol-diesel-pr...

# %%
temp_i_list = list()
for i in non_redun_Scraped_News.index:
    if non_redun_Scraped_News.loc[i, "Headline"].startswith("Mist-shrouded churches, eerie shipwrecks and "):
        print(i)
        temp_i_list.append(i)
# Out:
# 4697
# 4708
# 4709

# %%
for i in non_redun_Scraped_News.loc[temp_i_list, "Headline"].tolist():
    print(i)
    print("-"*115)
# Out:
# Mist-shrouded churches, eerie shipwrecks and magical doorways: The incredible winning images in the Historic Photographer of the Year 2020 contest
# -------------------------------------------------------------------------------------------------------------------
# Mist-shrouded churches, eerie shipwrecks and magical doorways: The incredible winning images in the Historic Photographer of the Year 2020 contest
# -------------------------------------------------------------------------------------------------------------------
# Mist-shrouded churches, eerie shipwrecks and magical doorways: The incredible winning images in the Historic Photographer of the Year 2020 contest
# -------------------------------------------------------------------------------------------------------------------

# %%
non_redun_Scraped_News.loc[temp_i_list, :]
# Out:
#                  Datetime Category Subcategory  \
# 4697  2020-12-22 19:17:00     News       syria
# 4708  2020-11-27 13:24:00     News       syria
# 4709  2020-11-26 15:24:00     News       syria
#
#                                                Headline  \
# 4697  Mist-shrouded churches, eerie shipwrecks and m...
# 4708  Mist-shrouded churches, eerie shipwrecks and m...
# 4709  Mist-shrouded churches, eerie shipwrecks and m...
#
#                                                 Summary  \
# 4697  This year's awards called on photographers to ...
# 4708  The winning and shortlisted images in the Hist...
# 4709  The winning and shortlisted images in the Hist...
#
#                                             Entire_News  \
# 4697  These incredible pictures offer a window to hi...
# 4708  These incredible pictures offer a window to hi...
# 4709  These incredible pictures offer a window to hi...
#
#                                   Author  \
# 4697             By MailOnline Reporter
# 4708             By MailOnline Reporter
# 4709  By Jennifer Newton for MailOnline
#
#                                               News_Link
# 4697  https://www.dailymail.co.uk/galleries/article-...
# 4708  https://www.dailymail.co.uk/galleries/article-...
# 4709  https://www.dailymail.co.uk/travel/escape/arti...

# %% [markdown]
# # Exporting the Dataframe as CSV

# %%
non_redun_Scraped_News.to_csv("Final_Reformatted_Clean_Corpus.csv", index=False)
